# %%
import numpy as np
import matplotlib.pyplot as plt
import spiceypy as spice

# %%
# SPICE test
spice.tkvrsn('TOOLKIT')
# Out:
# 'CSPICE_N0067'

# %% [markdown]
# Import SPICE user Lib

# %%
import sys

# import SPICE user lib
sys.path.append('../lib/')
import clipper_spice_lib as clipper_lib
import juice_spice_lib as juice_lib

# %% [markdown]
# Load SPICE kernels

# %%
# load SPICE ketnels
#source_dir = 'C:/share/Linux/doc/spice/clipper/kernels/'
source_dir = '/Users/Shared/spice/clipper/kernels/'
clipper_lib.spice_ini(source_dir)

# %% [markdown]
# S/C orbit near Earth

# %%
# set date/time
utctim = '2024-10-11T00:00:00'    # start date/time
et_ex = spice.str2et(utctim)      # seconds
nd = 60*24*30  # number of data
dt = 60   # time step [second]
et = et_ex + dt * np.arange(0, nd)

# calculate target position with spice

x, y, z, r, lat, lon = juice_lib.get_pos_xref(
    et, ref='IAU_EARTH', tar='EUROPA CLIPPER', org='EARTH', x_ref='SUN', corr='LT+S')

# %%
# plot
re = 6400.0  # km
plt.plot(x/re, y/re)
plt.title('Europa clipper orbit')
plt.xlabel('Distance from Earth [Re]')
plt.ylabel('Distance from Earth [Re]')
plt.show()

# %% [markdown]
# S/C orbit from Earth to Jupiter

# %%
# set date/time
utctim = '2024-10-11T00:00:00'    # start date/time
et_ex = spice.str2et(utctim)      # seconds
nd = 365*8 # number of data
dt = 60*60*24   # time step [second]
et = et_ex + dt * np.arange(0, nd)

# calculate target position with spice
x, y, z, r, lat, lon = juice_lib.get_pos_xref(
    et, ref='IAU_SUN', tar='EUROPA CLIPPER', org='SUN', x_ref='JUPITER', corr='LT+S')

# %%
from astropy.constants import au

# plot
au_km=au*1e-3
plt.plot(x/au_km, y/au_km)
plt.title('Europa clipper orbit')
plt.xlabel('Distance from Sun [A.U.]')
plt.ylabel('Distance from Sun [A.U.]')
plt.show()

# %%
# plot
td = spice.et2datetime(et)
plt.plot(td, r/au_km)
plt.title('Europa clipper orbit')
plt.xlabel('Year')
plt.ylabel('Distance from Sun [A.U.]')
plt.show()

# %% [markdown]
# S/C orbit around Jupiter (after JOI)

# %%
# set date/time
utctim = '2030-01-01T00:00:00'    # start date/time
et_ex = spice.str2et(utctim)      # seconds
nd = 24*365*4  # number of data
dt = 60*60     # time step [second]
et = et_ex + dt * np.arange(0, nd)

# calculate target position with spice
x, y, z, r, lat, lon = juice_lib.get_pos_xref(
    et, ref='IAU_JUPITER', tar='EUROPA CLIPPER', org='JUPITER', x_ref='SUN', corr='LT+S')

# %%
# plot
rj = 71400.0  # [km]
plt.figure(figsize=(10, 15))
plt.plot(x/rj, y/rj)
plt.title('Europa clipper orbit / Sun : + X direction')
plt.xlabel('Distance from Jupiter [RJ]')
plt.ylabel('Distance from Jupiter [RJ]')
plt.show()

# %%
# plot
td = spice.et2datetime(et)
rj = 71400.0  # [km]
plt.figure(figsize=(16, 4))
plt.plot(td, r/rj)
plt.title('Europa clipper orbit')
plt.xlabel('Year')
plt.ylabel('Distance from Jupiter [RJ]')
plt.show()

# %%
# set date/time
utctim = '2031-01-01T00:00:00'    # start date/time
et_ex = spice.str2et(utctim)      # seconds
nd = 24*365*3.6  # number of data
dt = 60*60    # time step [second]
et = et_ex + dt * np.arange(0, nd)

# calculate target position with spice
x, y, z, r, lat, lon = juice_lib.get_pos_xref(
    et, ref='IAU_JUPITER', tar='EUROPA CLIPPER', org='JUPITER', x_ref='SUN', corr='LT+S')

# %%
fig, (ax1, ax2) = plt.subplots(
    1, 2, figsize=(15.0, 6.0))

# plot
rj = 71400.0  # [km]
ax1.plot(x/rj, y/rj)
ax1.set_title('Europa clipper orbit / Sun : + X direction')
ax1.set_xlabel('X distance from Jupiter [RJ]')
ax1.set_ylabel('Y distance from Jupiter [RJ]')

ax2.plot(x/rj, z/rj)
ax2.set_title('Europa clipper orbit / Sun : + X direction')
ax2.set_xlabel('X distance from Jupiter [RJ]')
ax2.set_ylabel('Z distance from Jupiter [RJ]')
# Out:
# Text(0, 0.5, 'Z distance from Jupiter [RJ]')

# %% [markdown]
# S/C orbit around Jupiter & Europa

# %%
# set date/time
utctim = '2031-01-01T00:00:00'    # start date/time
et_ex = spice.str2et(utctim)      # seconds
nd = int(24*365*3.6)  # number of data
dt = 60*60     # time step [second]
et = et_ex + dt * np.arange(0, nd)

# calculate target position with spice
x, y, z, r, lat, lon = juice_lib.get_pos(et, ref='IAU_EUROPA', tar='EUROPA CLIPPER', org='EUROPA')

# %%
# plot
rj = 71400.0  # [km]

td = spice.et2datetime(et)
plt.figure(figsize=(16, 4))
plt.plot(td, r/rj)
plt.title('Europa clipper orbit')
plt.xlabel('Year')
plt.ylabel('Distance from Europa [RJ]')
plt.show()

# %% [markdown]
# S/C orbit around Europa

# %%
# set date/time
utctim = '2031-01-01T00:00:00'    # start date/time
et_ex = spice.str2et(utctim)      # seconds
nd = int(60*24*365*3.6)  # number of data
dt = 60    # time step [second]
et = et_ex + dt * np.arange(0, nd)

# calculate target position with spice
x, y, z, r, lat, lon = juice_lib.get_pos(
    et, 'IAU_EUROPA', 'EUROPA CLIPPER', 'EUROPA')

# %%
# plot
plt.plot(x, y)
prange = 10000.0
plt.xlim(-prange, prange)
plt.ylim(-prange, prange)
plt.title('EUROPA Clipper orbit')
plt.xlabel('X distance from EUROPA [km] (+:Jupiterward)')
plt.ylabel('Y distance from EUROPA [km]')

plt.show()

# %%
# plot
td = spice.et2datetime(et)
plt.figure(figsize=(16, 4))
plt.plot(td, r)
plt.ylim(0.0, 100000.0)
plt.title('EUROPA Clipper orbit')
plt.xlabel('Year')
plt.ylabel('Distance from EUROPA [km]')
plt.show()

# %% [markdown]
# Calculate Europa's orbital phase angle

# %%
# calculate target position with spice
xj, yj, zj, rj, latj, lonj = juice_lib.get_pos(et, ref='IAU_JUPITER', tar='EUROPA', org='JUPITER')

import scipy

ind = scipy.signal.argrelmax(rj)
npnt = len(ind[0][:])
phase = np.zeros(nd)
for i in range(0, npnt-1):
    nn = len(r[ind[0][i]:ind[0][i+1]])
    for j in range(nn):
        phase[ind[0][i]+j] = float(j)/float(nn)*360.0

# %% [markdown]
# Search closest approach

# %%
ca_time = []
ca_dist = []

for i in range(1,int(nd)-2):
    if r[i] < r[i-1] and r[i] < r[i+1] and r[i] < 20000.0:
        ca_time.append(td[i])
        ca_dist.append(r[i])

n = len(ca_time)
for i in range(n):
    print(i,ca_time[i], ca_dist[i])

plt.plot(td, r)
plt.plot(ca_time, ca_dist, '+')
plt.ylim(0.0, 100000.0)
plt.xlabel('Year')
plt.ylabel('Distance from EUROPA [km]')
plt.show()
# Out:
# 0 2031-03-07 02:39:59.998448+00:00 2194.530751004845
# 1 2031-03-27 14:02:59.998269+00:00 1841.4049088197771
# 2 2031-05-27 13:02:59.998892+00:00 1613.050588544546
# 3 2031-06-17 20:06:59.999419+00:00 1612.7248579505351
# 4 2031-07-09 03:13:00.000008+00:00 1615.9756278481436
# 5 2031-07-30 10:40:00.000585+00:00 1597.9900160798682
# 6 2031-08-20 18:09:00.001077+00:00 1651.7217612449515
# 7 2031-09-11 01:37:00.001420+00:00 1610.8399652364205
# 8 2031-10-02 09:07:00.001565+00:00 1656.7659851435035
# 9 2031-10-23 21:46:00.001490+00:00 1585.8251338304476
# 10 2031-11-14 05:17:00.001201+00:00 1597.9332342031807
# 11 2031-12-05 12:57:00.000735+00:00 1628.478467291608
# 12 2032-01-20 16:45:59.999443+00:00 1616.0164857843897
# 13 2032-02-11 00:21:59.998897+00:00 1595.9953621860159
# 14 2032-03-03 07:49:59.998492+00:00 1662.9260884362545
# 15 2032-03-24 15:38:59.998279+00:00 1895.7582326239378
# 16 2032-04-11 10:41:59.998269+00:00 1590.3772093850057
# 17 2032-04-25 23:53:59.998375+00:00 1636.1121041583638
# 18 2032-05-13 13:34:59.998626+00:00 1615.763208782928
# 19 2032-05-28 02:33:59.998921+00:00 1660.8921766488786
# 20 2032-06-14 15:59:59.999354+00:00 1601.881666889596
# 21 2032-06-29 04:50:59.999751+00:00 1648.191336599364
# 22 2032-07-16 18:34:00.000241+00:00 1593.5307294557215
# 23 2032-07-31 08:07:00.000627+00:00 1660.906509582133
# 24 2032-08-18 02:36:00.001039+00:00 1599.6526479075237
# 25 2032-09-01 07:17:00.001297+00:00 4218.158690555559
# 26 2033-05-27 16:01:59.998905+00:00 1654.8715126638267
# 27 2033-06-14 16:21:59.999347+00:00 1601.4456409280926
# 28 2033-06-28 10:56:59.999723+00:00 1618.6922807826984
# 29 2033-07-16 11:48:00.000226+00:00 1589.1688699213203
# 30 2033-07-30 06:32:00.000593+00:00 1684.3842346490246
# 31 2033-08-13 11:33:00.000934+00:00 1613.1714692095716
# 32 2033-08-27 16:29:00.001216+00:00 1602.138492432485
# 33 2033-09-10 21:24:00.001423+00:00 1617.2729065220276
# 34 2033-09-25 02:18:00.001542+00:00 1588.8638158433664
# 35 2033-10-09 07:12:00.001565+00:00 1601.3089692581736
# 36 2033-10-23 12:07:00.001489+00:00 1616.5411756982392
# 37 2033-11-06 16:56:00.001318+00:00 1595.357075617462
# 38 2033-11-20 20:45:00.001062+00:00 2454.5044897479966
# 39 2033-12-15 07:31:00.000466+00:00 1588.8018815393568
# 40 2034-01-09 04:14:59.999757+00:00 1612.4895394214245
# 41 2034-01-23 08:43:59.999357+00:00 1665.8095096481654
# 42 2034-02-06 13:25:59.998991+00:00 1613.8763471989719
# 43 2034-03-03 10:04:59.998498+00:00 1597.6833197908434
# 44 2034-03-28 06:35:59.998266+00:00 1583.535644190761
# 45 2034-04-11 11:16:59.998267+00:00 1585.3831835028875
# 46 2034-04-25 15:55:59.998366+00:00 1609.3161496016007
# 47 2034-05-09 20:52:59.998554+00:00 1597.323259706022
# 48 2034-05-24 01:44:59.998821+00:00 1597.3398046456202
# 49 2034-06-07 06:40:59.999150+00:00 1612.8913911789432
# 50 2034-06-21 11:37:59.999523+00:00 1599.6143585583754
# 51 2034-07-05 16:33:59.999918+00:00 1635.370987181454
# 52 2034-07-20 03:38:00.000319+00:00 1635.2548660269838

# %% [markdown]
# Apparent diameter of Europa seen from Europa Clipper

# %%
re = 1560.8  # [km]
appdia = 2.0*np.arctan(re/r) / np.pi * 180.0  # degree

# Spatial resolution of UVIS onboard Europa clipper : 0.15 deg/pixel　（SPIE paper)
# Spatial resolution of UVIS onboard Europa clipper : 
#   0.16 deg (airglow port), 0.06 deg (high spatial resolution port)    
#   https://europa.nasa.gov/spacecraft/instruments/europa-uvs/
#pltscl=0.15
pltscl=0.06

n1 = sum(x > pltscl*20 for x in appdia)
n2 = sum(x > pltscl*10 for x in appdia)
n3 = sum(x > pltscl*4 for x in appdia)
print("Total time [day]: ", float(nd)/60.0/24.0)
print("Time when spatial resolution < 0.1Re [day]: ", float(n1)/60.0/24.0)
print("Time when spatial resolution < 0.2Re [day]: ", float(n2)/60.0/24.0)
print("Time when spatial resolution < 0.5Re [day]: ", float(n3)/60.0/24.0)

# plot
plt.figure(figsize=(16, 4))
plt.plot(td, appdia, label='Europa [deg]')
xx = [td[0], td[len(td)-1]]
yy1 = [pltscl*20, pltscl*20]
yy2 = [pltscl*10, pltscl*10]
yy3 = [pltscl*4, pltscl*4]
plt.plot(xx, yy1, label='20 div')
plt.plot(xx, yy2, label='10 div')
plt.plot(xx, yy3, label='4 div')
plt.title('Apparent diameter of Europa seen from Europa Clipper')
plt.xlabel('Year')
plt.ylabel('degree')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# Total time [day]:  1314.0
# Time when spatial resolution < 0.1Re [day]:  44.66180555555556
# Time when spatial resolution < 0.2Re [day]:  82.07222222222222
# Time when spatial resolution < 0.5Re [day]:  152.51180555555555

# %%
utctim1 = '2031-07-07T00:00:00'
utctim2 = '2031-07-11T00:00:00'
td1 = spice.et2datetime(spice.str2et(utctim1))
td2 = spice.et2datetime(spice.str2et(utctim2))
index = np.where((td>td1) & (td<td2))

# plot
fig = plt.figure(figsize=(16.0, 8.0))

ax1 = fig.add_subplot(2,1,1)
ax1.plot(td[index], appdia[index], label='Europa [deg]')
xx = [td1, td2]
ax1.plot(xx, yy1, label='20 div')
ax1.plot(xx, yy2, label='10 div')
ax1.plot(xx, yy3, label='4 div')
ax1.set_xlim(td1, td2)
ax1.set_title('Apparent diameter of Europa seen from Europa Clipper')
ax1.set_xlabel('Time')
ax1.set_ylabel('degree')
ax1.set_yscale('log')
ax1.legend()

ax2 = fig.add_subplot(2,1,2)
ax2.plot(td, phase, label='Phase')
ax2.set_xlim(td1, td2)
ax2.set_xlabel('Time')
ax2.set_ylabel('degree')
ax2.set_yscale('linear')
ax2.legend()

# %%
#re = 1560.8  # [km]
#idx = np.where(r > re*2)
idx = np.where(appdia < pltscl*20)

xx=x
xx[idx] = np.nan
yy=y
yy[idx] = np.nan
zz=z
zz[idx] = np.nan
rr=r
rr[idx] = np.nan

llat=lat
llat[idx] = np.nan
llon=lon
llon[idx] = np.nan

lphase = phase
lphase[idx] = np.nan

prange = 40.0

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18.0, 6.0), sharex=True, sharey=True)

#ax1.scatter(x/re, y/re, s=1.0)
ax1.plot(xx/re, yy/re)
#ax1.plot(xx[index]/re, yy[index]/re)
ax1.set_xlim(-prange, prange)
ax1.set_ylim(-prange, prange)
ax1.set_title('EUROPA Clipper orbit')
ax1.set_xlabel('X distance from EUROPA [Re]')
ax1.set_ylabel('Y distance from EUROPA [Re]')

#ax2.scatter(y/re, z/re, s=1.0)
ax2.plot(yy/re, zz/re)
#ax2.plot(yy[index]/re, zz[index]/re)
ax2.set_xlim(-prange, prange)
ax2.set_ylim(-prange, prange)
ax2.set_title('EUROPA Clipper orbit')
ax2.set_xlabel('Y distance from EUROPA [Re]')
ax2.set_ylabel('Z distance from EUROPA [Re]')

ax3.plot(xx/re, zz/re)
#ax3.plot(xx[index]/re, zz[index]/re)
ax3.set_xlim(-prange, prange)
ax3.set_ylim(-prange, prange)
ax3.set_title('EUROPA Clipper orbit')
ax3.set_xlabel('X distance from EUROPA [Re]')
ax3.set_ylabel('Z distance from EUROPA [Re]')
# Out:
# Text(0, 0.5, 'Z distance from EUROPA [Re]')

# %%
plt.figure(figsize=(12, 6))
plt.scatter(llon*180.0/np.pi, llat*180.0/np.pi,s=3.0)
#plt.scatter(llon[index]*180.0/np.pi, llat[index]*180.0/np.pi, s=15.0)
plt.title('EUROPA Clipper orbit')
plt.xlabel('Longitude [deg]')
plt.ylabel('Latitude [deg]')
plt.show()

# %%
#utctim1 = '2031-07-01T00:00:00'
#utctim2 = '2031-07-31T00:00:00'
#td1 = spice.et2datetime(spice.str2et(utctim1))
#td2 = spice.et2datetime(spice.str2et(utctim2))

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12.0, 8.0))

ax1.scatter(td, llat*180.0/np.pi, s=3.0)
#ax1.scatter(td[index], llat[index]*180.0/np.pi, s=15.0)
ax1.set_title('EUROPA Clipper orbit')
ax1.set_xlabel('Date')
#ax1.set_xlim(td1,td2)
ax1.set_ylabel('Latitude [deg]')

ax2.scatter(td, llon*180.0/np.pi, s=3.0)
#ax2.scatter(td[index], llon[index]*180.0/np.pi, s=15.0)
ax2.set_xlabel('Date')
#ax2.set_xlim(td1,td2)
ax2.set_ylabel('Longitude [deg]')

ax3.scatter(td, lphase, s=3.0)
#ax3.scatter(td[index], lphase[index], s=15.0)
ax3.set_xlabel('Date')
#ax3.set_xlim(td1,td2)
ax3.set_ylabel('Phase angle [deg]')
# Out:
# Text(0, 0.5, 'Phase angle [deg]')
